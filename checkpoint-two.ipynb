# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
#Firstly, import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# create dataframe from the .csv  
df = pd.read_csv(r"/Users/cathleen/Downloads/StudentPerformanceFactors.csv")
#Use to_string to see the entire dataframe
print(df.to_string())

# Compile info about the the dataframe including the column names, non-nulls amd datatypes.

df.head()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality School_Type Peer_Influence  Physical_Activity Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0                23          84                  Low                High                         No            7               73              Low             Yes                  0           Low          Medium      Public       Positive                  3                    No              High School               Near    Male          67
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# Look at the first 10 entries
df.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
# 7             25          78                  Low                High
# 8             17          94               Medium                High
# 9             23          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# ...

# %%
# And the last 10.
df.tail(10)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6597             16          91                 High              Medium
# 6598              9          87                  Low              Medium
# 6599             30          94               Medium                 Low
# 6600             12          98               Medium                 Low
# 6601             20          83               Medium                 Low
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6597                        Yes            6               72
# ...

# %%
# Using .shape to get the nmber of rows (students) and columns.
df.shape
# Out:
# (6607, 20)

# %%
#What are the names of the 20 columns?
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
#Get a summary of the data set, including the data types and non-null counts.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
#The above shows us there are some nulls. Finding the count of  null (missing values) in the dataset.
df.isna().sum()
# 78 nulls for Teacher_Quality, 90 for Parental_Education_Level and 67 for Distance_from_Home.  Make note and decide to ignore or to deal with these.
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
# Here we'll do summary statistics for the 7 numerical columns.  
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
# This gives me the number of unique repsonses to each of the questions.  
df.nunique()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Peer_Influence                 3
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
# Here I'll seperate out a variable for the 13 categorical columns.  I may want to work with them separately from the numerical columns.
categorical_columns=[col for col in df.columns if df[col].dtype=='object']
categorical_columns
# Out:
# ['Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Motivation_Level',
#  'Internet_Access',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender']

# %%
#Nummerial columns are given a variable. 
numerical_columns= df.select_dtypes(include='number')
numerical_columns
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                     0                  3          67
# 1                     2                  4          61
# ...

# %%
# Get the range of scores from the numberical columns.  
max_score = numerical_columns.max()
max_score
min_score = numerical_columns.min()
min_score
score_ranges = max_score - min_score
score_ranges
# Out:
# Hours_Studied        43
# Attendance           40
# Sleep_Hours           6
# Previous_Scores      50
# Tutoring_Sessions     8
# Physical_Activity     6
# Exam_Score           46
# dtype: int64

# %%
#Some statisitcs for the numerical columns:
numerical_columns.std()
# Out:
# Hours_Studied         5.990594
# Attendance           11.547475
# Sleep_Hours           1.468120
# Previous_Scores      14.399784
# Tutoring_Sessions     1.230570
# Physical_Activity     1.031231
# Exam_Score            3.890456
# dtype: float64

# %%
numerical_columns.var()
# Out:
# Hours_Studied         35.887221
# Attendance           133.344178
# Sleep_Hours            2.155377
# Previous_Scores      207.353789
# Tutoring_Sessions      1.514304
# Physical_Activity      1.063438
# Exam_Score            15.135646
# dtype: float64

# %%
#Counting (frequency) for the 13 categorical columms:
#1
df.Parental_Education_Level.value_counts(dropna=False)
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# NaN               90
# Name: count, dtype: int64

# %%
#2
df.Parental_Involvement.value_counts()
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64

# %%
#3
df.Extracurricular_Activities.value_counts()

# %%
#4
df.Access_to_Resources.value_counts()
# Out:
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64

# %%
#5
df.Motivation_Level.value_counts()
# Out:
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64

# %%
#6
df.Family_Income.value_counts()
# Out:
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64

# %%
#7

df.Teacher_Quality.value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
#8
df.Internet_Access.value_counts()
# Out:
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64

# %%
#9
df.Peer_Influence.value_counts()
# Out:
# Peer_Influence
# Positive    2638
# Neutral     2592
# Negative    1377
# Name: count, dtype: int64

# %%
#10
df.Learning_Disabilities.value_counts()
# Out:
# Learning_Disabilities
# No     5912
# Yes     695
# Name: count, dtype: int64

# %%
#11
df.Parental_Education_Level.value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
#12
df.Distance_from_Home.value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %%
#13
df.Gender.value_counts()
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %% [markdown]
#  I'll begin with bar plots of each categorical columns vs. exam score to see if anything jumps out at me.
# 'Parental_Involvement',
# 'Access_to_Resources',
# 'Extracurricular_Activities',
# 'Motivation_Level',
# 'Internet_Access',
# 'Family_Income',
# 'Teacher_Quality',
# 'School_Type',
# 'Peer_Influence',
# 'Learning_Disabilities',
# 'Parental_Education_Level',
# 'Distance_from_Home',
# 'Gender'

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Parental_Education_Level',y='Exam_Score',data=df)
plt.title('Parent Education on Exam score')
plt.xlabel('Parent Education Level')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Parental_Involvement',y='Exam_Score',data=df)
plt.title('Parent Involement on Exam score')
plt.xlabel('Parent Involvement')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Access_to_Resources',y='Exam_Score',data=df)
plt.title('How do resources affect exam score?')
plt.xlabel('Resources')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Extracurricular_Activities',y='Exam_Score',data=df)
plt.title('How do resources affect exam score?')
plt.xlabel('Resources')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Motivation_Level',y='Exam_Score',data=df)
plt.title('Motivation vs Exam Score')
plt.xlabel('Motivation')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Internet_Access',y='Exam_Score',data=df)
plt.title('Internet vs exam score?')
plt.xlabel('Internet Access')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Family_Income',y='Exam_Score',data=df)
plt.title('Family Income vs Exam Score')
plt.xlabel('Family Income')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Teacher_Quality',y='Exam_Score',data=df)
plt.title('Teacher Quality vs Exam Score?')
plt.xlabel('Teacher Quality')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='School_Type',y='Exam_Score',data=df)
plt.title('School Type vs Exam Score?')
plt.xlabel('Public or Private School')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Peer_Influence',y='Exam_Score',data=df)
plt.title('PeerInfluence  vs Exam Score')
plt.xlabel('Peer Influence')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Learning_Disabilities',y='Exam_Score',data=df)
plt.title('Learning Disabilities vs Exam Score')
plt.xlabel('Learning Disability?')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Distance_from_Home',y='Exam_Score',data=df)
plt.title('Distance from Home vs Exam Score')
plt.xlabel('Distance from Home')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Gender',y='Exam_Score',data=df)
plt.title('Gender vs Exam Score?')
plt.xlabel('Gender')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %% [markdown]
# The above bar charts do not show anything interesting. I'll move forward wo the numerical columns to see if any of those could be significan to the exam scores.
#
# I'll move forward with the numerical columns.

# %%
# First,taking a closer look at the distribution of the numerical columns with histograms for each of the following:
import seaborn as sns   
sns.color_palette("tab10")

sns.histplot(df['Exam_Score'])
plt.title('Distribution of Exam Scores')
plt.show()

# %%
sns.histplot(df['Hours_Studied'])
plt.title('Distribution of Hours Studied')
plt.show()

# %%
sns.histplot(df['Attendance'])
plt.show()

# %%
sns.histplot(df['Sleep_Hours'])
plt.show()

# %%
sns.histplot(df['Previous_Scores'])
plt.show()

# %%
sns.histplot(df['Tutoring_Sessions'])
plt.show()

# %%
sns.histplot(df['Physical_Activity'])
plt.show()

# %% [markdown]
# Moving to scatterplots to see realtions to exam scores.

# %%
# Using scatterplots, I'll see if the exam scores have  any correlation categorical columns.  
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Physical_Activity'])
plt.title('Relationship Between Score and Physical Activity')
plt.xlabel('Exam Score')
plt.ylabel('Physical Activity')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Tutoring_Sessions'])
plt.title('Relationship Between Score and Number of Tutoring Sessions')
plt.xlabel('Exam Score')
plt.ylabel('Tutoring Sessions')
plt.grid(True)
plt.show()

# %%
# Relating some of these Factors to EXAM SCORES:
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Previous_Scores'])
plt.title('Relationship Between Score and Previous Scores')
plt.xlabel('Exam Score')
plt.ylabel('Previous Score')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Sleep_Hours'])
plt.title('Relationship Between Score and Sleep')
plt.xlabel('Exam Score')
plt.ylabel('Hours of Sleep')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Attendance'])
plt.title('Relationship Between Score and Attendance')
plt.xlabel('Exam Score')
plt.ylabel('Attendance')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Exam_Score'], df['Hours_Studied'])
plt.title('Relationship Between Score and Study Hours')
plt.xlabel('Exam Score')
plt.ylabel('Study Hours')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
#
#     I was surprised that I couldn't see a path forward until the last two scatterplots. They have a shape that seems to say somthing about the data.   It looks like there might be something to explore there.   I thought it would be very easy to see what was influenced exam score the most but it took quite a while to get an idea of how to proceed.
#
# 2. Do you have any concerns about your dataset?
#
#     I'm very unsure at this point on how I am going to establish a correlation between these variable and exam score.  I'll need to do a lot of digging into the resources to figure out an approach.
#
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
#     There are null values in the 3 columns:  Parental_Education_Level, Distance_from_Home, and Teacher_Quality.  Unsure if there are statistically significant number of nulls and I should reomove them or if I can leave them in.   I'm leaning towards removing those rows.
